# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
#df=pd.read_csv("all3_merged_chron.csv")
df=pd.read_csv("pp_pe_merged_chron.csv")

# %% [markdown]
# ## Missing values

# %%
temp = pd.DataFrame(df.isna().sum().sort_values(ascending=False)*100/df.shape[0],columns=['missing %'])
temp.style.background_gradient(cmap='Purples')
# Out:
# <style  type="text/css" >
#     #T_c50317a8_fdb4_11eb_9495_acde48001122row0_col0 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row1_col0 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row2_col0 {
#             background-color:  #41047f;
#             color:  #f1f1f1;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row3_col0 {
#             background-color:  #42057f;
#             color:  #f1f1f1;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row4_col0 {
#             background-color:  #450b82;
#             color:  #f1f1f1;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row5_col0 {
#             background-color:  #450b82;
#             color:  #f1f1f1;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row6_col0 {
#             background-color:  #62429c;
#             color:  #f1f1f1;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row7_col0 {
#             background-color:  #796eb2;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row8_col0 {
#             background-color:  #9f9cc9;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row9_col0 {
#             background-color:  #bebfdd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row10_col0 {
#             background-color:  #bfc0de;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row11_col0 {
#             background-color:  #bfc0de;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row12_col0 {
#             background-color:  #bfc0de;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row13_col0 {
#             background-color:  #c0c1de;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row14_col0 {
#             background-color:  #c1c2df;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row15_col0 {
#             background-color:  #c1c2df;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row16_col0 {
#             background-color:  #c1c2df;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row17_col0 {
#             background-color:  #c1c2df;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row18_col0 {
#             background-color:  #c1c2df;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row19_col0 {
#             background-color:  #c1c2df;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row20_col0 {
#             background-color:  #c1c2df;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row21_col0 {
#             background-color:  #c1c2df;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row22_col0 {
#             background-color:  #c1c2df;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row23_col0 {
#             background-color:  #c1c2df;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row24_col0 {
#             background-color:  #d8d8ea;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row25_col0 {
#             background-color:  #ebe9f3;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row26_col0 {
#             background-color:  #f8f7fb;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row27_col0 {
#             background-color:  #faf8fb;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row28_col0 {
#             background-color:  #faf9fc;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row29_col0 {
#             background-color:  #faf9fc;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row30_col0 {
#             background-color:  #fbfafc;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row31_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row32_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row33_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row34_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row35_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row36_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row37_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row38_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row39_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row40_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row41_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row42_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row43_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row44_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row45_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row46_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row47_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row48_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row49_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row50_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row51_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row52_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row53_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row54_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row55_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row56_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row57_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row58_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50317a8_fdb4_11eb_9495_acde48001122row59_col0 {
#             background

# %%
## Deleting columns and their pairs above a certain percentage missing

def delete(threshold_prec,df):
    temp = pd.DataFrame(df.isna().sum().sort_values(ascending=False)*100/df.shape[0],columns=['missing %'])
    f=temp.index
    a=list(temp[temp["missing %"]>threshold_prec].index)
    for i in a:
        c=str(i[:-1])
        d=[x for x in f if c in x]
        for j in d:
            if j not in a:
                a.append(j)
    df.drop(columns=a,inplace=True)

delete(50,df)
temp = pd.DataFrame(df.isna().sum().sort_values(ascending=False)*100/df.shape[0],columns=['missing %'])
temp.style.background_gradient(cmap='Purples')
# Out:
# <style  type="text/css" >
#     #T_c50a9a28_fdb4_11eb_9495_acde48001122row0_col0 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row1_col0 {
#             background-color:  #40017e;
#             color:  #f1f1f1;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row2_col0 {
#             background-color:  #40017e;
#             color:  #f1f1f1;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row3_col0 {
#             background-color:  #40027e;
#             color:  #f1f1f1;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row4_col0 {
#             background-color:  #42057f;
#             color:  #f1f1f1;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row5_col0 {
#             background-color:  #430780;
#             color:  #f1f1f1;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row6_col0 {
#             background-color:  #430780;
#             color:  #f1f1f1;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row7_col0 {
#             background-color:  #430780;
#             color:  #f1f1f1;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row8_col0 {
#             background-color:  #430780;
#             color:  #f1f1f1;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row9_col0 {
#             background-color:  #430780;
#             color:  #f1f1f1;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row10_col0 {
#             background-color:  #430780;
#             color:  #f1f1f1;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row11_col0 {
#             background-color:  #430780;
#             color:  #f1f1f1;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row12_col0 {
#             background-color:  #430780;
#             color:  #f1f1f1;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row13_col0 {
#             background-color:  #430780;
#             color:  #f1f1f1;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row14_col0 {
#             background-color:  #430780;
#             color:  #f1f1f1;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row15_col0 {
#             background-color:  #705ca9;
#             color:  #f1f1f1;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row16_col0 {
#             background-color:  #b3b3d6;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row17_col0 {
#             background-color:  #f5f4f9;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row18_col0 {
#             background-color:  #f6f4f9;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row19_col0 {
#             background-color:  #f6f4f9;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row20_col0 {
#             background-color:  #f8f7fb;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row21_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row22_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row23_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row24_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row25_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row26_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row27_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row28_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row29_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row30_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row31_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row32_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row33_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row34_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row35_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row36_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row37_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row38_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row39_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row40_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row41_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row42_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row43_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row44_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row45_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row46_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row47_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row48_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row49_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row50_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c50a9a28_fdb4_11eb_9495_acde48001122row51_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }</style><table id="T_c50a9a28_fdb4_11eb_9495_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >missing %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c50a9a28_fdb4_11eb_9495_acde48001122level0_row0" class="row_heading level0 row0" >Kaplan is most concerned with everyone's safety and security. If in-person education cannot resume in a timely fashion, how comfortable are you with continuing your education online?_y</th>
#                         <td id="T_c50a9a28_fdb4_11eb_9495_acde48001122row0_col0" class="data row0 col0" >36.376742</td>
#             </tr>
#             <tr>
#                         <th id="T_c50a9a28_fdb4_11eb_9495_acde48001122level0_row1" class="row_heading level0 row1" >NPS class_y</th>
#                         <td id="T_c50a9a28_fdb4_11eb_9495_acde48001122row1_col0" class="data row1 col0" >36.136473</td>
#             </tr>
#             <tr>
#                         <th id="T_c50a9a28_fdb4_

# %%
## Handling remaining missing values:
import missingno as msno

sorted = df[df.columns[df.isnull().any()].tolist()].sort_values('NPS class_y')
#msno.matrix(sorted)
msno.heatmap(sorted)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Missing values higly correlated, instead of deleting columns itself which may lead to loss of important independent variable, I am deleting rows, as the missing values are highly correlated this action will remove missing datapoints for most of the features.

# %%
#deleting features whose missing values are not correlated and >30%
df=df[df["Technical support_y"].notnull()]
temp = pd.DataFrame(df.isna().sum().sort_values(ascending=False)*100/df.shape[0],columns=['missing %'])
temp.style.background_gradient(cmap='Purples')
# Out:
# <style  type="text/css" >
#     #T_c6342068_fdb4_11eb_9495_acde48001122row0_col0 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row1_col0 {
#             background-color:  #440a82;
#             color:  #f1f1f1;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row2_col0 {
#             background-color:  #8885be;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row3_col0 {
#             background-color:  #f4f2f8;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row4_col0 {
#             background-color:  #f5f4f9;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row5_col0 {
#             background-color:  #f5f4f9;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row6_col0 {
#             background-color:  #f8f7fa;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row7_col0 {
#             background-color:  #f8f7fb;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row8_col0 {
#             background-color:  #f9f8fb;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row9_col0 {
#             background-color:  #f9f8fb;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row10_col0 {
#             background-color:  #fbfafc;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row11_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row12_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row13_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row14_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row15_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row16_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row17_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row18_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row19_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row20_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row21_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row22_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row23_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row24_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row25_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row26_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row27_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row28_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row29_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row30_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row31_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row32_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row33_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row34_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row35_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row36_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row37_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row38_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row39_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row40_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row41_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row42_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row43_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row44_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row45_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row46_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row47_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row48_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row49_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row50_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_c6342068_fdb4_11eb_9495_acde48001122row51_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }</style><table id="T_c6342068_fdb4_11eb_9495_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >missing %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c6342068_fdb4_11eb_9495_acde48001122level0_row0" class="row_heading level0 row0" >How easy was it to access the online content?</th>
#                         <td id="T_c6342068_fdb4_11eb_9495_acde48001122row0_col0" class="data row0 col0" >31.967213</td>
#             </tr>
#             <tr>
#                         <th id="T_c6342068_fdb4_11eb_9495_acde48001122level0_row1" class="row_heading level0 row1" >How easy was it to navigate the website to find relevant product options?</th>
#                         <td id="T_c6342068_fdb4_11eb_9495_acde48001122row1_col0" class="data row1 col0" >30.923994</td>
#             </tr>
#             <tr>
#                         <th id="T_c6342068_fdb4_11eb_9495_acde48001122level0_row2" class="row_heading level0 row2" >How easy

# %% [markdown]
# ## Class
# Survey 1 --> 3
#
# Detractors -> Passive (D_Pa) (Increase)
#
# Detractors -> Promoters (D_pr) (Increase)
#
# Passive -> Promoters (Pa_Pr) (Increase)
#
# Passive -> Detractors (Pa_D) (Decrease)
#
# Promoters -> Passive (Pr_Pa) (Decrease)
#
# Promoters -> Detractors (Pr_D) (Decrease)
#
# data very less, better to analyse feature contribution towards increase or decrease in the positive attitude towards the product. Then we will have only 3 classes **"Increase", "Decrease"
# and "same"**.
#
# "Increase" class represent students whose opinion improved and so on

# %%
### change 
import numpy as np
df.reset_index(drop=True,inplace=True)
df["change"]="Same"
for i in range(df.shape[0]):
    if((df.loc[i,"NPS class_x"]=="Detractors") & (df.loc[i,"NPS class_y"]=="Passive")):
        df.at[i,"change"]="Increase"
    if((df.at[i,"NPS class_x"]=="Detractors") & (df.at[i,"NPS class_y"]=="Promoters")):
        df.at[i,"change"]="Increase"
    if((df.at[i,"NPS class_x"]=="Passive") & (df.at[i,"NPS class_y"]=="Promoters")):
        df.at[i,"change"]="Increase"
    if((df.at[i,"NPS class_x"]=="Passive") & (df.at[i,"NPS class_y"]=="Detractors")):
        df.at[i,"change"]="Decrease"
    if((df.at[i,"NPS class_x"]=="Promoters" )& (df.at[i,"NPS class_y"]=="Passive")):
        df.at[i,"change"]="Decrease"
    if((df.at[i,"NPS class_x"]=="Promoters") & (df.at[i,"NPS class_y"]=="Detractors")):
        df.at[i,"change"]="Decrease"

# %%
df.head(3)
# Out:
#    Unnamed: 0  Respondent ID_x  Collector ID_x         Start Date_x  \
# 0           8      12776208672       406636855  2021-06-27 08:20:00
# 1          14      12775430864       406636248  2021-06-26 15:36:00
# 2          40      12706588986       405312395  2021-01-06 15:27:00
#
#          End Date_x     IP Address_x                    Email Address_x  \
# 0  27-06-2021 08:22  174.219.128.203               msandbulte@gmail.com
# 1  26-06-2021 15:39     67.5.112.118                       lsan@att.net
# 2  01-06-2021 15:29    173.18.14.110  tclement@midwesternsecurities.com
#
#   First Name_x Last Name_x Custom Data 4_x  Custom Data 5  Brand reputation_x  \
# 0      Melissa    Aanenson     Real Estate        8487016                   4
# 1        Lynda     Sanders       Insurance        8680595                   3
# 2         Tira     Clement      Securities        8800978                   3
#
#    Price_x  Pass guarantee_x  Technical support_x  Quality of the product_x  \
# 0        4                 4                    4                         4
# 1        3                 0                    1                         4
# 2        3                 4                    4                         4
#
#    Study materials available on a mobile device_x  \
# 0                                               4
# 1                                               0
# 2                                               4
#
#    Variety of the study materials_x  Difficulty of the practice questions_x  \
# 0                                 4                                       2
# 1                                 1                                       2
# 2                                 2                                       3
#
#    Quantity of the practice questions_x  \
# 0                                     2
# 1                                     2
# 2                                     3
#
#    Course content that can be applied to the "Real World"_x  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
#
#    How easy was it to navigate the website to find relevant product options?  \
# 0                                                3.0
# 1                                                3.0
# 2                                                NaN
#
#    How easy was it to complete your purchase?  \
# 0                                         3.0
# 1                                         3.0
# 2                                         NaN
#
#    I am confident that I will achieve the goals that I set for myself.  \
# 0                                                3.0
# 1                                                3.0
# 2                                                3.0
#
#    How easy was it to access the online content?  \
# 0                                            3.0
# 1                                            3.0
# 2                                            2.0
#
#    Based on your recent experience, how likely are you to recommend Kaplan to a friend or colleague?  \
# 0                                                6.0
# 1                                               10.0
# 2                                                7.0
#
#    Kaplan is most concerned with everyone's safety and security. If in-person education cannot resume in a timely fashion, how comfortable are you with continuing your education online?_x  \
# 0                                                3.0
# 1                                                4.0
# 2                                                2.0
#
#   NPS class_x  Respondent ID_y  Collector ID_y         Start Date_y  \
# 0  Detractors      12399322033       399807393  2021-10-02 13:10:00
# 1   Promoters      12396508852       399807917  2021-09-02 16:30:00
# 2     Passive      12549547170       402673005  2021-05-04 14:15:00
#
#          End Date_y   IP Address_y                    Email Address_y  \
# 0  10-02-2021 13:13   216.16.54.90               msandbulte@gmail.com
# 1  09-02-2021 16:38   174.31.24.72                       lsan@att.net
# 2  05-04-2021 14:17  173.18.14.110  tclement@midwesternsecurities.com
#
#   First Name_y Last Name_y        Custom Data 4_y  \
# 0      Melissa    Aanenson  Real Estate Licensing
# 1        Lynda     Sanders              LICENSING
# 2         Tira     Clement             SECURITIES
#
#    How did you do on your exam?  Brand reputation_y  Price_y  \
# 0                             3                 0.0      0.0
# 1                             1                 4.0      3.0
# 2                             3                 2.0      2.0
#
#    Pass guarantee_y  Technical support_y  Quality of the product_y  \
# 0               0.0                  0.0                       0.0
# 1               3.0                  3.0                       3.0
# 2               0.0                  2.0                       2.0
#
#    Study materials available on a mobile device_y  \
# 0                                             0.0
# 1                                             0.0
# 2                                             3.0
#
#    Variety of the study materials_y  Difficulty of the practice questions_y  \
# 0                               0.0                                     2.0
# 1                               4.0                                     3.0
# 2                               2.0                                     2.0
#
#    Quantity of the practice questions_y  \
# 0                                   0.0
# 1                                   4.0
# 2                                   3.0
#
#    Course content that can be applied to the "Real World"_y  \
# 0                                                0.0
# 1                                                4.0
# 2                                                2.0
#
#    I am confident that I achieved the goals that I set for myself.  \
# 0                                                0.0
# 1                                                3.0
# 2                                                1.0
#
#    How likely are you to recommend Kaplan to a friend or colleague?  \
# 0                                                0.0
# 1                                                7.0
# 2                                               10.0
#
#    Kaplan is most concerned with everyone's safety and security. If in-person education cannot resume in a timely fashion, how comfortable are you with continuing your education online?_y  \
# 0                                                0.0
# 1                                                4.0
# 2                                                4.0
#
#   NPS class_y    change
# 0  Detractors      Same
# 1     Passive  Decrease
# 2   Promoters  Increase

# %% [markdown]
# ## Feature Engineering
#
# Now that our target variable is also  based on change, we would do the same for independent variables. eg
# **"Brand reputation"** we have 2 scores for the 2 surveys, instead of using the scores, we would use change in scores.
#
# Similarly for each independent variables which are present in both the surveys we calculate the change in scores, which represents how the opinion of student changed.

# %%
col=["Unnamed: 0","Respondent ID_x","Collector ID_x","IP Address_x","Email Address_x","First Name_x","Last Name_x"
     ,"Respondent ID_y","Collector ID_y","End Date_y","End Date_x","IP Address_y","Email Address_y",
     "First Name_y","Last Name_y","Custom Data 4_x","Custom Data 4_y","Custom Data 5"]
df.drop(columns=col,inplace=True)

#time between 2 surveys
df['Start Date_x'] = pd.to_datetime(df['Start Date_x'])
df['Start Date_y'] = pd.to_datetime(df['Start Date_y'])
df["TimeDiff"]=(df["Start Date_y"]-df["Start Date_x"]).dt.days
df.drop(columns=["Start Date_x","Start Date_y"],inplace=True)

#change in ratings
a=[x for x in df.columns if (("_" in x) and ((df[x].dtype==np.int64) | (df[x].dtype==np.float64)))]
c=[x.split("_")[0] for x in a]
for i in set(c):
    name=i+str("_change")
    df[name]=df[i+"_y"]-df[i+"_x"]
df.drop(columns=a,inplace=True)

# deleting their ratings as we are only focusing on how their ratings influence their overall NPS class.
a=["NPS class_x","NPS class_y"]
df.drop(columns=a,inplace=True)

# %% [markdown]
# ## Modeling
#
# Now we have 3 classes "same","Increase","decrease", we could perform a multiclass classification and perform inference
# to find out the key drivers. Using **Xgboost for multiclass classification**

# %%
# xgboost

from sklearn.model_selection import train_test_split
X=df.loc[:,~df.columns.isin(["change"])]
y=df.loc[:,df.columns.isin(["change"])]
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    stratify=y, 
                                                    test_size=0.15)
X_train.reset_index(drop=True,inplace=True)
X_test.reset_index(drop=True,inplace=True)
y_train.reset_index(drop=True,inplace=True)
y_test.reset_index(drop=True,inplace=True)

# %%
##grid search hyperparameter training

# from xgboost import XGBClassifier
# from sklearn.model_selection import StratifiedKFold
# from sklearn.model_selection import RandomizedSearchCV, GridSearchCV


# params = {"learning_rate"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ] ,
#  "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
#  "min_child_weight" : [ 1, 3, 5, 7 ],
#  "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
#  "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ] }

# xgb = XGBClassifier(learning_rate=0.02, n_estimators=600, objective='multi:softprob',
#                     silent=True, nthread=1)

# folds = 3
# param_comb = 10

# skf = StratifiedKFold(n_splits=folds, shuffle = True, random_state = 1001)
# import sklearn
# scorer = sklearn.metrics.make_scorer(sklearn.metrics.f1_score, average = 'weighted')

# random_search = RandomizedSearchCV(xgb, param_distributions=params, n_iter=param_comb, scoring=scorer, n_jobs=4, cv=skf.split(X_train,y_train), verbose=False, random_state=1001 )

# random_search.fit(X_train, y_train)

# print('\n Best weighted F1 score for %d-fold search with %d parameter combinations:' % (folds, param_comb))
# print(random_search.best_score_ * 2 - 1)
# print('\n Best hyperparameters:')
# print(random_search.best_params_)

# %%
import xgboost as xgb
from matplotlib import pyplot

params={'min_child_weight': 3, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 0.0, 
        'colsample_bytree': 0.7,"objective":"multi:softprob"}

xgb1=xgb.XGBClassifier(**params)

eval_set = [(X_train, y_train), (X_test, y_test)]

model = xgb1.fit(X_train, y_train, eval_metric=["mlogloss"], eval_set=eval_set, verbose=False)

results = model.evals_result()

epochs = len(results['validation_0']['mlogloss'])
x_axis = range(0, epochs)
# plot log loss
fig, ax = pyplot.subplots()
ax.plot(x_axis, results['validation_0']['mlogloss'], label='Train')
ax.plot(x_axis, results['validation_1']['mlogloss'], label='Test')
ax.legend()
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

pyplot.ylabel('Log Loss')
pyplot.title('XGBoost Log Loss')

pyplot.show()
# from sklearn.metrics import accuracy_score
# print("Accuracy for model : %.2f" % (accuracy_score(y_test.values.ravel(), model.predict(X_test)) * 100))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %% [markdown]
# ## Using Shap to understand relation and correlation between the features and the change in Students opinion
#
# Aim is to find how the change in **students opinion** (target variable) is related to **change in scores of differet questions** between the 2 surveys ( independent variable).
# Given that we have built the dependent and independent variables mostly on change in scores, the correlation we measure is much more specific compared to if the variables used were normal scores of the 2 surveys instead of change.

# %%
import shap
# monkey patch
mybooster = model.get_booster() 
model_bytearray = mybooster.save_raw()[4:]
def myfun(self=None):
    return model_bytearray
mybooster.save_raw = myfun

# shap expaliner
explainer = shap.TreeExplainer(mybooster)
shap_values = explainer.shap_values(X_train)
shap.summary_plot(shap_values, X_train)
# Out:
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %% [markdown]
# **Overall parameter importance from Shap**

# %% [markdown]
# ## Correlation between features and target.

# %%
## feature effects for "2" class i.e, "Increase"

def feature_contri(X_train,shap_values,clas):
    a=(pd.DataFrame(shap_values[clas],columns=X_train.columns).sum())
    a=pd.DataFrame(a,columns=["effect_magnitude"])
    a["correlation"]="positive"
    a.loc[a["effect_magnitude"]<0,"correlation"]="negative"
    a["effect_magnitude"]=abs(a["effect_magnitude"])
    a.sort_values(by="effect_magnitude",inplace=True,ascending=False)
    def highlight_greaterthan(s, column):
        is_max = pd.Series(data=False, index=s.index)
        is_max[column] = s.loc[column] == "negative"
        return ['background-color: #ffe6e6' if is_max.any() else 'background-color: #e6ffe6' for v in is_max]

    return a.style.apply(highlight_greaterthan, column=['correlation'], axis=1)

feature_contri(X_train,shap_values,2)
# Out:
# <style  type="text/css" >
#     #T_c794f0a4_fdb4_11eb_9495_acde48001122row0_col0 {
#             background-color:  #e6ffe6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row0_col1 {
#             background-color:  #e6ffe6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row1_col0 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row1_col1 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row2_col0 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row2_col1 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row3_col0 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row3_col1 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row4_col0 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row4_col1 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row5_col0 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row5_col1 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row6_col0 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row6_col1 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row7_col0 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row7_col1 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row8_col0 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row8_col1 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row9_col0 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row9_col1 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row10_col0 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row10_col1 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row11_col0 {
#             background-color:  #e6ffe6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row11_col1 {
#             background-color:  #e6ffe6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row12_col0 {
#             background-color:  #e6ffe6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row12_col1 {
#             background-color:  #e6ffe6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row13_col0 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row13_col1 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row14_col0 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row14_col1 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row15_col0 {
#             background-color:  #e6ffe6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row15_col1 {
#             background-color:  #e6ffe6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row16_col0 {
#             background-color:  #e6ffe6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row16_col1 {
#             background-color:  #e6ffe6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row17_col0 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row17_col1 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row18_col0 {
#             background-color:  #e6ffe6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row18_col1 {
#             background-color:  #e6ffe6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row19_col0 {
#             background-color:  #ffe6e6;
#         }    #T_c794f0a4_fdb4_11eb_9495_acde48001122row19_col1 {
#             background-color:  #ffe6e6;
#         }</style><table id="T_c794f0a4_fdb4_11eb_9495_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >effect_magnitude</th>        <th class="col_heading level0 col1" >correlation</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c794f0a4_fdb4_11eb_9495_acde48001122level0_row0" class="row_heading level0 row0" >How likely are you to recommend Kaplan to a friend or colleague?</th>
#                         <td id="T_c794f0a4_fdb4_11eb_9495_acde48001122row0_col0" class="data row0 col0" >287.729980</td>
#                         <td id="T_c794f0a4_fdb4_11eb_9495_acde48001122row0_col1" class="data row0 col1" >positive</td>
#             </tr>
#             <tr>
#                         <th id="T_c794f0a4_fdb4_11eb_9495_acde48001122level0_row1" class="row_heading level0 row1" >I am confident that I achieved the goals that I set for myself.</th>
#                         <td id="T_c794f0a4_fdb4_11eb_9495_acde48001122row1_col0" class="data row1 col0" >12.436909</td>
#                         <td id="T_c794f0a4_fdb4_11eb_9495_acde48001122row1_col1" class="data row1 col1" >negative</td>
#             </tr>
#             <tr>
#                         <th id="T_c794f0a4_fdb4_11eb_9495_acde48001122level0_row2" class="row_heading level0 row2" >Kaplan is most concerned with everyone's safety and security. If in-person education cannot resume in a timely fashion, how comfortable are you with continuing your education online?_change</th>
#                         <td id="T_c794f0a4_fdb4_11eb_9495_acde48001122row2_col0" class="data row2 col0" >11.278142</td>
#                         <td id="T_c794f0a4_fdb4_11eb_9495_acde48001122row2_col1" class="data row2 col1" >negative</td>
#             </tr>
#             <tr>
#                         <th id="T_c794f0a4_fdb4_11eb_9495_acde48001122level0_row3" class="row_heading level0 row3" >How easy was it to navigate the website to find relevant product options?</th>
#                         <td id="T_c794f0a4_fdb4_11eb_9495_acde48001122row3_col0" class="data row3 col0" >8.944852</td>
#                         <td id="T_c794f0a4_fdb4_11eb_9495_acde48001122row3_col1" class="data row3 col1" >negative</td>
#             </tr>
#             <tr>
#                         <th id="T_c794f0a4_fdb4_11eb_9495_acde48001122level0_row4" class="row_heading level0 row4" >How easy was it to complete your purchase?</th>
#                         <td id="T_c794f0a4_fdb4_11eb_9495_acde48001122row4_col0" class="data row4 col0" >3.542038</td>
#                         <td id="T_c794f0a4_fdb4_11eb_9495_acde48001122row4_col1" class="data row4 col1" >negative</td>
#             </tr>
#             <tr>
#                         <th id="T_c794f0a4_fdb4_11eb_9495_acde48001122level0_row5" class="row_heading level0 row5" >I am confident that I will achieve the goals that I set for myself.</th>
#                         <td id="T_c794f0a4_fdb4_11eb_9495_acde48001122row5_col0" class="data row5 col0" >3.381141</td>
#                         <td id="T_c794f0a4_fdb4_11eb_9495_acde48001122row5_col1" class="data row5 col1" >negative</td>
#             </tr>
#             <tr>
#                         <th id="T_c794f0a4_fdb4_11eb_9495_acde48001122level0_row6" class="row_heading level0 row6" >TimeDiff</th>
#                         <td id="T_c794f0a4_fdb4_11eb_9495_acde48001122row6_col0" class="data row6 col0" >3.070317</td>
#                         <td id="T_c794f0a4_fdb4_11eb_9495_acde48001122row6_col1" class="data row6 col1" >negative</td>
#             </tr>
#             <tr>
#                         <th id="T_c794f0a4_fdb4_11eb_9495_acde48001122level0_row7" class="row_heading level0 row7" >Quality of the product_change</th>
#                         <td id="T_c794f0a4_fdb4_11eb_9495_acde48001122row7_col0"

# %% [markdown]
# So the above dataframe shows the effect of increase or decrease of feature values on the respective class, from the
# above dataframe if **"How likely are you to recommend Kaplan to a friend or colleague?"** value is high then this has a positive effect on "2" class, that means a student is more probable to improve his opinion.
#
# **"negative correlation"** between **price change** and **change in student opinion**
# **positive correlation** between **pass gurantee** and **change in student opinion**
